# %%
import pandas as pd
import numpy as np

# %%
movies_df = pd.read_csv("E:datamining-master/movies.csv", usecols=['movieId','title'], 
                        sep=';',dtype={'movieId': 'int32', 'title': 'str'})

# %%
movies_df.head()
# Out:
#    movieId                               title
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)

# %%
movies_df.shape
# Out:
# (9742, 2)

# %%
rating_df = pd.read_csv("E:datamining-master/ratings.csv", usecols=['userId','movieId','rating'], 
                        sep=';',dtype={'userId': 'int32', 'movieId': 'int32','rating': 'float32'})

# %%
rating_df.head()
# Out:
#    userId  movieId  rating
# 0       1        1     4.0
# 1       1        3     4.0
# 2       1        6     4.0
# 3       1       47     5.0
# 4       1       50     5.0

# %%
rating_df.shape
# Out:
# (100836, 3)

# %%
df = pd.merge(rating_df,movies_df, on = 'movieId')
df
# Out:
#         userId  movieId  rating                             title
# 0            1        1     4.0                  Toy Story (1995)
# 1            5        1     4.0                  Toy Story (1995)
# 2            7        1     4.5                  Toy Story (1995)
# 3           15        1     2.5                  Toy Story (1995)
# 4           17        1     4.5                  Toy Story (1995)
# ...        ...      ...     ...                               ...
# 100831     610   160341     2.5                  Bloodmoon (1997)
# 100832     610   160527     4.5  Sympathy for the Underdog (1971)
# 100833     610   160836     3.0                     Hazard (2005)
# 100834     610   163937     3.5                Blair Witch (2016)
# 100835     610   163981     3.5                         31 (2016)
#
# [100836 rows x 4 columns]

# %%
combine_movie_rating = df.dropna(axis = 0, subset = ['title'])
movie_ratingCount = (combine_movie_rating.groupby(by = ['title'])['rating'].count().reset_index().rename(columns = {'rating': 'totalRatingCount'})[['title','totalRatingCount']])
movie_ratingCount
# Out:
#                                           title  totalRatingCount
# 0                                    '71 (2014)                 1
# 1       'Hellboy': The Seeds of Creation (2004)                 1
# 2                        'Round Midnight (1986)                 2
# 3                           'Salem's Lot (2004)                 1
# 4                     'Til There Was You (1997)                 2
# ...                                         ...               ...
# 9714                            eXistenZ (1999)                22
# 9715                                 xXx (2002)                24
# 9716             xXx: State of the Union (2005)                 5
# 9717                      ¡Three Amigos! (1986)                26
# 9718  À nous la liberté (Freedom for Us) (1931)                 1
#
# [9719 rows x 2 columns]

# %%
rating_with_totalRatingCount = combine_movie_rating.merge(movie_ratingCount, left_on = 'title', right_on = 'title', how = 'left')
rating_with_totalRatingCount.head()
# Out:
#    userId  movieId  rating             title  totalRatingCount
# 0       1        1     4.0  Toy Story (1995)               215
# 1       5        1     4.0  Toy Story (1995)               215
# 2       7        1     4.5  Toy Story (1995)               215
# 3      15        1     2.5  Toy Story (1995)               215
# 4      17        1     4.5  Toy Story (1995)               215

# %%
pd.set_option('display.float.format', lambda x: '%.3f' %x)
print(movie_ratingCount['totalRatingCount'].describe())
# Out:
# count   9719.000
# mean      10.375
# std       22.406
# min        1.000
# 25%        1.000
# 50%        3.000
# 75%        9.000
# max      329.000
# Name: totalRatingCount, dtype: float64

# %%
popularity_treshold = 300
rating_popular_movie = rating_with_totalRatingCount.query('totalRatingCount >= @popularity_treshold')
rating_popular_movie.head()
# Out:
#       userId  movieId  rating                title  totalRatingCount
# 1819       1      296   3.000  Pulp Fiction (1994)               307
# 1820       4      296   1.000  Pulp Fiction (1994)               307
# 1821       5      296   5.000  Pulp Fiction (1994)               307
# 1822       6      296   2.000  Pulp Fiction (1994)               307
# 1823       8      296   4.000  Pulp Fiction (1994)               307

# %%
rating_popular_movie.shape
# Out:
# (953, 5)

# %%
## first lets create a pivot matrix

movie_features_df = rating_popular_movie.pivot_table(index = 'title', columns = 'userId', values = 'rating').fillna(0)
movie_features_df.head()
# Out:
# userId                            1     2     4     5     6     7     8    \
# title
# Forrest Gump (1994)             4.000 0.000 0.000 0.000 5.000 5.000 3.000
# Pulp Fiction (1994)             3.000 0.000 1.000 5.000 2.000 0.000 4.000
# Shawshank Redemption The (1994) 0.000 3.000 0.000 3.000 5.000 0.000 5.000
#
# userId                            10    11    14   ...   601   602   603  \
# title                                              ...
# Forrest Gump (1994)             3.500 5.000 4.000  ... 0.000 3.000 3.000
# Pulp Fiction (1994)             1.000 0.000 3.000  ... 0.000 5.000 5.000
# Shawshank Redemption The (1994) 0.000 4.000 3.000  ... 5.000 5.000 0.000
#
# userId                            604   605   606   607   608   609   610
# title
# Forrest Gump (1994)             0.000 3.000 4.000 0.000 3.000 4.000 3.000
# Pulp Fiction (1994)             5.000 2.000 5.000 3.000 5.000 4.000 5.000
# Shawshank Redemption The (1994) 0.000 0.000 3.500 5.000 4.500 4.000 3.000
#
# [3 rows x 449 columns]

# %%
from scipy.sparse import csr_matrix
movie_features_df_matrix = csr_matrix(movie_features_df.values)

from sklearn.neighbors import NearestNeighbors
model_kkn = NearestNeighbors(metric = 'cosine', algorithm= 'brute')
model_kkn.fit(movie_features_df_matrix)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine')

# %%
movie_features_df.head()
# Out:
# userId                            1     2     4     5     6     7     8    \
# title
# Forrest Gump (1994)             4.000 0.000 0.000 0.000 5.000 5.000 3.000
# Pulp Fiction (1994)             3.000 0.000 1.000 5.000 2.000 0.000 4.000
# Shawshank Redemption The (1994) 0.000 3.000 0.000 3.000 5.000 0.000 5.000
#
# userId                            10    11    14   ...   601   602   603  \
# title                                              ...
# Forrest Gump (1994)             3.500 5.000 4.000  ... 0.000 3.000 3.000
# Pulp Fiction (1994)             1.000 0.000 3.000  ... 0.000 5.000 5.000
# Shawshank Redemption The (1994) 0.000 4.000 3.000  ... 5.000 5.000 0.000
#
# userId                            604   605   606   607   608   609   610
# title
# Forrest Gump (1994)             0.000 3.000 4.000 0.000 3.000 4.000 3.000
# Pulp Fiction (1994)             5.000 2.000 5.000 3.000 5.000 4.000 5.000
# Shawshank Redemption The (1994) 0.000 0.000 3.500 5.000 4.500 4.000 3.000
#
# [3 rows x 449 columns]

# %%
query_index = np.random.choice(movie_features_df.shape[0])
print(query_index)
distance, indices = model_kkn.kneighbors(movie_features_df.iloc[query_index,:].values.reshape(1,-1), n_neighbors = 12)
# Out:
# 2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2376/3555800892.py in <module>
#       1 query_index = np.random.choice(movie_features_df.shape[0])
#       2 print(query_index)
# ----> 3 distance, indices = model_kkn.kneighbors(movie_features_df.iloc[query_index,:].values.reshape(1,-1), n_neighbors = 12)
#
# ~\anaconda3\lib\site-packages\sklearn\neighbors\_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     678         n_samples_fit = self.n_samples_fit_
#     679         if n_neighbors > n_samples_fit:
# --> 680             raise ValueError(
#     681                 "Expected n_neighbors <= n_samples, "
#     682                 " but n_samples = %d, n_neighbors = %d" %
#
# ValueError: Expected n_neighbors <= n_samples,  but n_samples = 3, n_neighbors = 12

# %%
movie_features_df.head()
# Out:
# userId                            1     2     4     5     6     7     8    \
# title
# Forrest Gump (1994)             4.000 0.000 0.000 0.000 5.000 5.000 3.000
# Pulp Fiction (1994)             3.000 0.000 1.000 5.000 2.000 0.000 4.000
# Shawshank Redemption The (1994) 0.000 3.000 0.000 3.000 5.000 0.000 5.000
#
# userId                            10    11    14   ...   601   602   603  \
# title                                              ...
# Forrest Gump (1994)             3.500 5.000 4.000  ... 0.000 3.000 3.000
# Pulp Fiction (1994)             1.000 0.000 3.000  ... 0.000 5.000 5.000
# Shawshank Redemption The (1994) 0.000 4.000 3.000  ... 5.000 5.000 0.000
#
# userId                            604   605   606   607   608   609   610
# title
# Forrest Gump (1994)             0.000 3.000 4.000 0.000 3.000 4.000 3.000
# Pulp Fiction (1994)             5.000 2.000 5.000 3.000 5.000 4.000 5.000
# Shawshank Redemption The (1994) 0.000 0.000 3.500 5.000 4.500 4.000 3.000
#
# [3 rows x 449 columns]

# %%
for i in range(0, len(distance.flatten())):
    if i == 0: 
        print('Recommendation for {0}:\n'.format(movie_features_df.index[query_index]))
    else:
        print('{0}: {1}, with distance of {2}: '.format(i,movie_features_df.index[indices.flatten()[i]], distance.flatten()[i]))
# Out:
# Recommendation for Forrest Gump (1994):
#
# 1: Shawshank Redemption The (1994), with distance of 0.2870066165924072:
