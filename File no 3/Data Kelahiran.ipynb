# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('E:datamining-master/dataset_soal No. 3.csv', usecols=['Usia','Kelahiran_ke-','Waktu_Kelahiran','Tekanan_darah','Kelainan_jantung','Caesarian'], 
                        sep=';',dtype={'Usia': 'int32', 'Kelahiran_ke-': 'int32', 'Waktu_Kelahiran': 'int32', 'Tekanan_darah': 'int32', 'Kelainan_jantung': 'int32', 'Caesarian': 'int32'})

# %%
df
# Out:
#     Usia  Kelahiran_ke-  Waktu_Kelahiran  Tekanan_darah  Kelainan_jantung  \
# 0     22              1                0              2                 0
# 1     26              2                0              1                 0
# 2     26              2                1              1                 0
# 3     28              1                0              2                 0
# 4     22              2                0              1                 0
# ..   ...            ...              ...            ...               ...
# 75    27              2                1              1                 0
# 76    33              4                0              1                 0
# 77    29              2                1              2                 0
# 78    25              1                2              0                 0
# 79    24              2                2              1                 0
#
#     Caesarian
# 0           0
# 1           1
# 2           0
# 3           0
# ...

# %%
import math 
dis = []
for i in range(80):
    dis.append(math.sqrt((float(df.iloc[i]['Usia'])-30)**2+
                         (float(df.iloc[i]['Kelahiran_ke-'])- 1)**2+
                         (float(df.iloc[i]['Waktu_Kelahiran'])-0)**2+
                         (float(df.iloc[i]['Tekanan_darah'])-1)**2))

# %%
df['dis'] = dis
df
# Out:
#     Usia  Kelahiran_ke-  Waktu_Kelahiran  Tekanan_darah  Kelainan_jantung  \
# 0     22              1                0              2                 0
# 1     26              2                0              1                 0
# 2     26              2                1              1                 0
# 3     28              1                0              2                 0
# 4     22              2                0              1                 0
# ..   ...            ...              ...            ...               ...
# 75    27              2                1              1                 0
# 76    33              4                0              1                 0
# 77    29              2                1              2                 0
# 78    25              1                2              0                 0
# 79    24              2                2              1                 0
#
#     Caesarian       dis
# 0           0  8.062258
# 1           1  4.123106
# ...

# %%
df.sort_values('dis')
# Out:
#     Usia  Kelahiran_ke-  Waktu_Kelahiran  Tekanan_darah  Kelainan_jantung  \
# 27    30              1                0              1                 0
# 38    31              1                0              1                 0
# 67    29              2                0              1                 1
# 54    29              2                0              1                 1
# 59    30              2                1              2                 1
# ..   ...            ...              ...            ...               ...
# 41    19              1                0              1                 0
# 61    19              1                0              1                 0
# 25    18              1                0              1                 0
# 26    18              1                1              2                 1
# 70    17              1                0              0                 0
#
#     Caesarian        dis
# 27          0   0.000000
# 38          0   1.000000
# ...

# %%
y = df.sort_values('dis').head(12)
y
# Out:
#     Usia  Kelahiran_ke-  Waktu_Kelahiran  Tekanan_darah  Kelainan_jantung  \
# 27    30              1                0              1                 0
# 38    31              1                0              1                 0
# 67    29              2                0              1                 1
# 54    29              2                0              1                 1
# 59    30              2                1              2                 1
# 49    29              2                0              0                 1
# 77    29              2                1              2                 0
# 28    32              1                0              2                 1
# 72    28              2                0              1                 0
# 63    32              2                0              1                 1
# 3     28              1                0              2                 0
# 8     28              2                0              1                 0
#
# ...

# %%
z = y["Caesarian"]
z
# Out:
# 27    0
# 38    0
# 67    0
# 54    1
# 59    1
# 49    1
# 77    1
# 28    1
# 72    0
# 63    1
# 3     0
# 8     0
# Name: Caesarian, dtype: int32

# %%
np.mean(z)
# Out:
# 0.5

# %%
df.to_excel('E:datamining-master/hasil_a.xls')
# Out:
# C:\Users\USER\AppData\Local\Temp/ipykernel_10276/4137035374.py:1: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   df.to_excel('E:datamining-master/hasil_a.xls')

# %%
import math 
dis = []
for i in range(80):
    dis.append(math.sqrt((float(df.iloc[i]['Usia'])-29)**2+
                         (float(df.iloc[i]['Kelahiran_ke-'])- 2)**2+
                         (float(df.iloc[i]['Waktu_Kelahiran'])-0)**2+
                         (float(df.iloc[i]['Tekanan_darah'])-2)**2))

# %%
df['dis'] = dis
df
# Out:
#     Usia  Kelahiran_ke-  Waktu_Kelahiran  Tekanan_darah  Kelainan_jantung  \
# 0     22              1                0              2                 0
# 1     26              2                0              1                 0
# 2     26              2                1              1                 0
# 3     28              1                0              2                 0
# 4     22              2                0              1                 0
# ..   ...            ...              ...            ...               ...
# 75    27              2                1              1                 0
# 76    33              4                0              1                 0
# 77    29              2                1              2                 0
# 78    25              1                2              0                 0
# 79    24              2                2              1                 0
#
#     Caesarian       dis
# 0           0  7.071068
# 1           1  3.162278
# ...

# %%
df.sort_values('dis')
# Out:
#     Usia  Kelahiran_ke-  Waktu_Kelahiran  Tekanan_darah  Kelainan_jantung  \
# 54    29              2                0              1                 1
# 77    29              2                1              2                 0
# 67    29              2                0              1                 1
# 59    30              2                1              2                 1
# 3     28              1                0              2                 0
# ..   ...            ...              ...            ...               ...
# 61    19              1                0              1                 0
# 26    18              1                1              2                 1
# 31    40              1                0              1                 1
# 25    18              1                0              1                 0
# 70    17              1                0              0                 0
#
#     Caesarian        dis
# 54          1   1.000000
# 77          1   1.000000
# ...

# %%
y = df.sort_values('dis').head(18)
y
# Out:
#     Usia  Kelahiran_ke-  Waktu_Kelahiran  Tekanan_darah  Kelainan_jantung  \
# 54    29              2                0              1                 1
# 77    29              2                1              2                 0
# 67    29              2                0              1                 1
# 59    30              2                1              2                 1
# 3     28              1                0              2                 0
# 35    28              3                0              2                 0
# 8     28              2                0              1                 0
# 72    28              2                0              1                 0
# 45    28              3                0              1                 1
# 66    28              3                0              1                 0
# 27    30              1                0              1                 0
# 49    29              2                0              0                 1
# ...

# %%
z = y["Caesarian"]
z
# Out:
# 54    1
# 77    1
# 67    0
# 59    1
# 3     0
# 35    1
# 8     0
# 72    0
# 45    1
# 66    1
# 27    0
# 49    1
# 6     0
# 40    1
# 33    1
# 75    0
# 38    0
# 52    0
# Name: Caesarian, dtype: int32

# %%
np.mean(z)
# Out:
# 0.5

# %%
df.to_excel('E:datamining-master/hasil_b.xls')
# Out:
# C:\Users\USER\AppData\Local\Temp/ipykernel_10276/2989725871.py:1: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   df.to_excel('E:datamining-master/hasil_b.xls')
